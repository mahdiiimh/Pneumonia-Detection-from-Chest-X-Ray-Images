# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle

# %%
cp /content/kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download paultimothymooney/chest-xray-pneumonia
# Out:
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# Downloading chest-xray-pneumonia.zip to /content
# 100% 2.29G/2.29G [01:19<00:00, 33.1MB/s]
# 100% 2.29G/2.29G [01:19<00:00, 31.1MB/s]

# %%
## JUST FOR ME
cp /content/drive/MyDrive/DataSets/chest-xray-pneumonia.zip /content/

# %%
! unzip -qq /content/chest-xray-pneumonia.zip

# %%
# !rm -rf /content/chest_xray/__MACOSX

# %%
# !rm -rf /content/chest_xray/test

# %%
# !rm -rf /content/chest_xray/train

# %%
# !rm -rf /content/chest_xray/val

# %%
import os
import shutil
# Define the input and output folder paths
input_folder_path = "/content/chest_xray/chest_xray"
output_folder_path = os.path.join(input_folder_path, "AllData")
classes = ["NORMAL", "PNEUMONIA"]

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# Loop through the train, test, and val folders
for split in ["test", "train", "val"]:
    split_folder_path = os.path.join(input_folder_path, split)
    # Loop through the NORMAL and PNEUMONIA folders in each split folder
    for class_name in classes:
        class_folder_path = os.path.join(split_folder_path, class_name)
        # Loop through the image files in each class folder and copy them to the output folder
        for file_name in os.listdir(class_folder_path):
            if file_name.endswith(".jpeg"):
                src_path = os.path.join(class_folder_path, file_name)
                dst_path = os.path.join(output_folder_path, class_name, file_name)
                # Create the class folder in the output folder if it doesn't exist
                if not os.path.exists(os.path.join(output_folder_path, class_name)):
                    os.makedirs(os.path.join(output_folder_path, class_name))
                # Copy the image file to the output folder
                shutil.copyfile(src_path, dst_path)

# %%
# !ls -1 /content/chest_xray/chest_xray/AllData/PNEUMONIA| wc -l
# Out:
# 4273

# %%
# !ls -1 /content/chest_xray/chest_xray/AllData/NORMAL| wc -l
# Out:
# 1583

# %%
import os
import shutil
import random

# Set the path to the "FinalDataset" folder
data_dir = "/content/chest_xray/chest_xray/AllData"
# Set the path to the output directory
output_dir = "/content/FinalDataset"

# Set the train/validation/test split ratios
train_ratio = 0.6
val_ratio = 0.2
test_ratio = 0.2

# Create the output directories
os.makedirs(os.path.join(output_dir, "train", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "train", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "val", "PNEUMONIA"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "NORMAL"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "test", "PNEUMONIA"), exist_ok=True)

# Get the list of image files in each class folder
normal_files = os.listdir(os.path.join(data_dir, "NORMAL"))
pneumonia_files = os.listdir(os.path.join(data_dir, "PNEUMONIA"))

# Shuffle the lists to randomize the order
random.shuffle(normal_files)
random.shuffle(pneumonia_files)

# Calculate the number of images for each split
num_normal = len(normal_files)
num_pneumonia = len(pneumonia_files)

num_train_normal = int(num_normal * train_ratio)
num_train_pneumonia = int(num_pneumonia * train_ratio)

num_val_normal = int(num_normal * val_ratio)
num_val_pneumonia = int(num_pneumonia * val_ratio)

num_test_normal = int(num_normal * test_ratio)
num_test_pneumonia = int(num_pneumonia * test_ratio)

# Copy the image files to the output directories for each split
for i, file in enumerate(normal_files):
    src_path = os.path.join(data_dir, "NORMAL", file)
    if i < num_train_normal:
        dst_path = os.path.join(output_dir, "train", "NORMAL", file)
    elif i < num_train_normal + num_val_normal:
        dst_path = os.path.join(output_dir, "val", "NORMAL", file)
    else:
        dst_path = os.path.join(output_dir, "test", "NORMAL", file)
    shutil.copy(src_path, dst_path)

for i, file in enumerate(pneumonia_files):
    src_path = os.path.join(data_dir, "PNEUMONIA", file)
    if i < num_train_pneumonia:
        dst_path = os.path.join(output_dir, "train", "PNEUMONIA", file)
    elif i < num_train_pneumonia + num_val_pneumonia:
        dst_path = os.path.join(output_dir, "val", "PNEUMONIA", file)
    else:
        dst_path = os.path.join(output_dir, "test", "PNEUMONIA", file)
    shutil.copy(src_path, dst_path)

print("Data has been split into train, val, and test sets.")
# Out:
# Data has been split into train, val, and test sets.

# %% [markdown]
# -----

# %%
train_dir='/content/FinalDataset/train'
test_dir = '/content/FinalDataset/test'
val_dir = '/content/FinalDataset/val'

# %%
train_normal_dir = os.path.join(train_dir, 'NORMAL')

train_pen_dir = os.path.join(train_dir, 'PNEUMONIA')

validation_normal_dir = os.path.join(val_dir, 'NORMAL')

validation_pen_dir = os.path.join(val_dir, 'PNEUMONIA')

test_normal_dir = os.path.join(test_dir, 'NORMAL')

test_pen_dir = os.path.join(test_dir, 'PNEUMONIA')
print('total training NORMAL images:', len(os.listdir(train_normal_dir)))
print('total training PNEUMONIA images:', len(os.listdir(train_pen_dir)))
print('total validation NORMAL images:', len(os.listdir(validation_normal_dir)))
print('total validation PNEUMONIA images:', len(os.listdir(validation_pen_dir)))
print('total test NORMAL images:', len(os.listdir(test_normal_dir)))
print('total test PNEUMONIA images:', len(os.listdir(test_pen_dir)))
# Out:
# total training NORMAL images: 949
# total training PNEUMONIA images: 2563
# total validation NORMAL images: 316
# total validation PNEUMONIA images: 854
# total test NORMAL images: 318
# total test PNEUMONIA images: 856

# %% [markdown]
# ---

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from keras import models
from keras import layers
import numpy as np
from sklearn.metrics import roc_auc_score, recall_score, f1_score, precision_score
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   horizontal_flip=True,
                                   zoom_range=0.2,
                                   fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
import keras.utils as image

fnames = [os.path.join(train_normal_dir, fname) for fname in os.listdir(train_normal_dir)]

img_path = fnames[1]

img = image.load_img(img_path)

x = image.img_to_array(img)

x = x.reshape((1,) + x.shape)

i = 0
for batch in train_datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    i += 1
    if i % 4 == 0:
        break

plt.show()

# %%
import keras.utils as image

fnames = [os.path.join(train_pen_dir, fname) for fname in os.listdir(train_pen_dir)]

img_path = fnames[1]

img = image.load_img(img_path)

x = image.img_to_array(img)

x = x.reshape((1,) + x.shape)

i = 0
for batch in train_datagen.flow(x, batch_size=1):
    plt.figure(i)
    imgplot = plt.imshow(image.array_to_img(batch[0]))
    i += 1
    if i % 4 == 0:
        break

plt.show()

# %%
train_generator = train_datagen.flow_from_directory( '/content/FinalDataset/train',
                                                    target_size=(128, 128),
                                                    batch_size=64,

                                                    class_mode='binary')
# Out:
# Found 3512 images belonging to 2 classes.

# %%
val_generator = val_datagen.flow_from_directory( '/content/FinalDataset/val',
                                                target_size=(128, 128),
                                                batch_size=64,

                                                class_mode='binary')
# Out:
# Found 1170 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory( '/content/FinalDataset/test',
                                                  target_size=(128, 128),
                                                  batch_size=1174,

                                                  class_mode='binary')
# Out:
# Found 1174 images belonging to 2 classes.

# %%
from keras.applications.efficientnet import EfficientNetB2

# %%
base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 [==============================] - 2s 0us/step

# %%
'''
# Sequential Model
model = models.Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(layers.Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))
'''
# Or Functional API
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
base_model.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 128, 128, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 128, 128, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 128, 128, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 129, 129, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 64, 64, 32)           864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 64, 64, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 64, 64, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 64, 64, 32)           288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 64, 64, 32)           128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 64, 64, 32)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 64, 64, 32)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 64, 64, 16)           512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 64, 64, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 64, 64, 16)           144       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 64, 64, 16)           64        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 64, 64, 16)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 16)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 16)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 4)              68        ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 16)             80        ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 64, 64, 16)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 64, 64, 16)           256       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 64, 64, 16)           64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 64, 64, 16)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 64, 64, 16)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 96)           1536      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 64, 64, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 65, 65, 96)           0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 32, 32, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 32, 32, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 32, 32, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 32, 32, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 32, 32, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 32, 32, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 32, 32, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 32, 32, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 32, 32, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 32, 32, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 32, 32, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 32, 32, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 32, 32, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 32, 32, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 32, 32, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 32, 32, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 32, 32, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 32, 32, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 32, 32, 144)          576       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 32, 32, 144)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 32, 32, 144)          1296      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 32, 32, 144)          576       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 32, 32, 144)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 144)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 32, 32, 144)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 32, 32, 24)           3456      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 32, 32, 24)           96        ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 32, 32, 24)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 32, 32, 24)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 144)          3456      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 35, 35, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 16, 16, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 16, 16, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 16, 16, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 16, 16, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 16, 16, 48)           6912      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 16, 16, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 16, 16, 288)          13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 16, 16, 288)          1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 16, 16, 288)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 16, 16, 288)          7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 16, 16, 288)          1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 16, 16, 288)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 16, 16, 288)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 16, 16, 48)           13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 16, 16, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 16, 16, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 16, 16, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 16, 16, 288)          13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 16, 16, 288)          1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 16, 16, 288)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 16, 16, 288)          7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 16, 16, 288)          1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 16, 16, 288)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 16, 16, 288)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 16, 16, 48)           13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 16, 16, 48)           192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 16, 16, 48)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 16, 16, 48)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 16, 16, 288)          13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 16, 16, 288)          1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 16, 16, 288)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 17, 17, 288)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 8, 8, 288)            2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 8, 8, 288)            1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 8, 8, 288)            0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 8, 8, 288)            0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 8, 8, 88)             25344     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 8, 8, 88)             352       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 8, 8, 528)            46464     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 8, 8, 528)            2112      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 8, 8, 528)            0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 8, 8, 528)            4752      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 8, 8, 528)            2112      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 8, 8, 528)            0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 528)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 528)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 22)             11638     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 528)            12144     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 8, 8, 528)            0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 8, 8, 88)             46464     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 8, 8, 88)             352       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 8, 8, 88)             0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 8, 8, 88)             0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 8, 8, 528)            46464     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 8, 8, 528)            2112      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 8, 8, 528)            0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 8, 8, 528)            4752      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 8, 8, 528)            2112      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 8, 8, 528)            0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 528)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 528)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 22)             11638     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 528)            12144     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 8, 8, 528)            0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 8, 8, 88)             46464     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 8, 8, 88)             352       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 8, 8, 88)             0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 8, 8, 88)             0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 8, 8, 528)            46464     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 8, 8, 528)            2112      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 8, 8, 528)            0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, 8, 8, 528)            4752      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, 8, 8, 528)            2112      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 8, 8, 528)            0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 528)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 528)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 22)             11638     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 528)            12144     ['block4d_se_reduce[0][0]']
#
# ...
#
#  block6d_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 4, 4, 208)            0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 4, 4, 208)            0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6d_add[0][0]']
#  D)
#
#  block6e_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block6e_expand_conv[0][0]']
#  rmalization)
#
#  block6e_expand_activation   (None, 4, 4, 1248)           0         ['block6e_expand_bn[0][0]']
#  (Activation)
#
#  block6e_dwconv (DepthwiseC  (None, 4, 4, 1248)           31200     ['block6e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6e_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block6e_dwconv[0][0]']
#  tion)
#
#  block6e_activation (Activa  (None, 4, 4, 1248)           0         ['block6e_bn[0][0]']
#  tion)
#
#  block6e_se_squeeze (Global  (None, 1248)                 0         ['block6e_activation[0][0]']
#  AveragePooling2D)
#
#  block6e_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6e_se_squeeze[0][0]']
#  e)
#
#  block6e_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, 4, 4, 208)            0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 4, 4, 208)            0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6e_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 4, 4, 1248)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 4, 4, 1248)           11232     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 4, 4, 1248)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1248)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 4, 4, 352)            439296    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 4, 4, 352)            1408      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 4, 4, 2112)           743424    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 4, 4, 2112)           8448      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 4, 4, 2112)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 4, 4, 2112)           19008     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 4, 4, 2112)           8448      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 4, 4, 2112)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2112)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2112)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 88)             185944    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2112)           187968    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 4, 4, 2112)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 4, 4, 352)            743424    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 4, 4, 352)            1408      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 4, 4, 352)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 4, 4, 352)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 4, 4, 1408)           495616    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 4, 4, 1408)           5632      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 4, 4, 1408)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1408)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)                  180352    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    65        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7957242 (30.35 MB)
# Trainable params: 188673 (737.00 KB)
# Non-trainable params: 7768569 (29.63 MB)
# __________________________________________________________________________________________________

# %%
base_model.trainable = True

# %%
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  340

# %%
fine_tune_at = 10
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 128, 128, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 128, 128, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 128, 128, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 129, 129, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 64, 64, 32)           864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 64, 64, 32)           128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 64, 64, 32)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 64, 64, 32)           288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 64, 64, 32)           128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 64, 64, 32)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 64, 64, 32)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 64, 64, 16)           512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 64, 64, 16)           64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 64, 64, 16)           144       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 64, 64, 16)           64        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 64, 64, 16)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 16)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 16)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 4)              68        ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 16)             80        ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 64, 64, 16)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 64, 64, 16)           256       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 64, 64, 16)           64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 64, 64, 16)           0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 64, 64, 16)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 96)           1536      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 64, 64, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 65, 65, 96)           0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 32, 32, 96)           864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 32, 32, 96)           384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 32, 32, 96)           0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 32, 32, 96)           0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 32, 32, 24)           2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 32, 32, 24)           96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 32, 32, 144)          3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 32, 32, 144)          576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 32, 32, 144)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 32, 32, 144)          1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 32, 32, 144)          576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 32, 32, 144)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 144)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 32, 32, 144)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 32, 32, 24)           3456      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 32, 32, 24)           96        ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 32, 32, 24)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 32, 32, 24)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 32, 32, 144)          3456      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 32, 32, 144)          576       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 32, 32, 144)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 32, 32, 144)          1296      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 32, 32, 144)          576       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 32, 32, 144)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 144)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 32, 32, 144)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 32, 32, 24)           3456      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 32, 32, 24)           96        ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 32, 32, 24)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 32, 32, 24)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 144)          3456      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 144)          576       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 144)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 35, 35, 144)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 16, 16, 144)          3600      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 16, 16, 144)          576       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 16, 16, 144)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 144)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 16, 16, 144)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 16, 16, 48)           6912      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 16, 16, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 16, 16, 288)          13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 16, 16, 288)          1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 16, 16, 288)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 16, 16, 288)          7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 16, 16, 288)          1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 16, 16, 288)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 16, 16, 288)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 16, 16, 48)           13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 16, 16, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 16, 16, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 16, 16, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 16, 16, 288)          13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 16, 16, 288)          1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 16, 16, 288)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 16, 16, 288)          7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 16, 16, 288)          1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 16, 16, 288)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 16, 16, 288)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 16, 16, 48)           13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 16, 16, 48)           192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 16, 16, 48)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 16, 16, 48)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 16, 16, 288)          13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 16, 16, 288)          1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 16, 16, 288)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 17, 17, 288)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 8, 8, 288)            2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 8, 8, 288)            1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 8, 8, 288)            0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 8, 8, 288)            0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 8, 8, 88)             25344     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 8, 8, 88)             352       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 8, 8, 528)            46464     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 8, 8, 528)            2112      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 8, 8, 528)            0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 8, 8, 528)            4752      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 8, 8, 528)            2112      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 8, 8, 528)            0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 528)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 528)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 22)             11638     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 528)            12144     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 8, 8, 528)            0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 8, 8, 88)             46464     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 8, 8, 88)             352       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 8, 8, 88)             0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 8, 8, 88)             0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 8, 8, 528)            46464     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 8, 8, 528)            2112      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 8, 8, 528)            0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 8, 8, 528)            4752      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 8, 8, 528)            2112      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 8, 8, 528)            0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 528)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 528)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 22)             11638     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 528)            12144     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 8, 8, 528)            0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 8, 8, 88)             46464     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 8, 8, 88)             352       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 8, 8, 88)             0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 8, 8, 88)             0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 8, 8, 528)            46464     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 8, 8, 528)            2112      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 8, 8, 528)            0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, 8, 8, 528)            4752      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, 8, 8, 528)            2112      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 8, 8, 528)            0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 528)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 528)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 22)             11638     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 528)            12144     ['block4d_se_reduce[0][0]']
#
# ...
#
#  block6d_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6d_activation[0][0]',
#  y)                                                                  'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6d_se_excite[0][0]']
#  2D)
#
#  block6d_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6d_project_conv[0][0]']
#  ormalization)
#
#  block6d_drop (Dropout)      (None, 4, 4, 208)            0         ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)           (None, 4, 4, 208)            0         ['block6d_drop[0][0]',
#                                                                      'block6c_add[0][0]']
#
#  block6e_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6d_add[0][0]']
#  D)
#
#  block6e_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block6e_expand_conv[0][0]']
#  rmalization)
#
#  block6e_expand_activation   (None, 4, 4, 1248)           0         ['block6e_expand_bn[0][0]']
#  (Activation)
#
#  block6e_dwconv (DepthwiseC  (None, 4, 4, 1248)           31200     ['block6e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block6e_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block6e_dwconv[0][0]']
#  tion)
#
#  block6e_activation (Activa  (None, 4, 4, 1248)           0         ['block6e_bn[0][0]']
#  tion)
#
#  block6e_se_squeeze (Global  (None, 1248)                 0         ['block6e_activation[0][0]']
#  AveragePooling2D)
#
#  block6e_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block6e_se_squeeze[0][0]']
#  e)
#
#  block6e_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block6e_se_reshape[0][0]']
#
#  block6e_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block6e_se_reduce[0][0]']
#
#  block6e_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block6e_activation[0][0]',
#  y)                                                                  'block6e_se_expand[0][0]']
#
#  block6e_project_conv (Conv  (None, 4, 4, 208)            259584    ['block6e_se_excite[0][0]']
#  2D)
#
#  block6e_project_bn (BatchN  (None, 4, 4, 208)            832       ['block6e_project_conv[0][0]']
#  ormalization)
#
#  block6e_drop (Dropout)      (None, 4, 4, 208)            0         ['block6e_project_bn[0][0]']
#
#  block6e_add (Add)           (None, 4, 4, 208)            0         ['block6e_drop[0][0]',
#                                                                      'block6d_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 4, 4, 1248)           259584    ['block6e_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 4, 4, 1248)           4992      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 4, 4, 1248)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 4, 4, 1248)           11232     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 4, 4, 1248)           4992      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 4, 4, 1248)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1248)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1248)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 52)             64948     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1248)           66144     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 4, 4, 1248)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 4, 4, 352)            439296    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 4, 4, 352)            1408      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 4, 4, 2112)           743424    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 4, 4, 2112)           8448      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 4, 4, 2112)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 4, 4, 2112)           19008     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 4, 4, 2112)           8448      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 4, 4, 2112)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2112)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2112)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 88)             185944    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2112)           187968    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 4, 4, 2112)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 4, 4, 352)            743424    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 4, 4, 352)            1408      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 4, 4, 352)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 4, 4, 352)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)           (None, 4, 4, 1408)           495616    ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 4, 4, 1408)           5632      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 4, 4, 1408)           0         ['top_bn[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1408)                 0         ['top_activation[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 128)                  180352    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 64)                   8256      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 64)                   0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 1)                    65        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7957242 (30.35 MB)
# Trainable params: 7888387 (30.09 MB)
# Non-trainable params: 68855 (268.97 KB)
# __________________________________________________________________________________________________

# %%
x_train, y_train = train_generator.next()

# %%
x_val, y_val = val_generator.next()

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)
class_weights = dict(enumerate(class_weights))

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow import keras

# %%
checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True,
save_weights_only=True, monitor='val_loss', mode='min', verbose=1)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
patience=10, min_lr=0.00001, verbose=1)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10,mode='min')

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_generator, validation_data=val_generator,
epochs=30,
batch_size=128,
callbacks=[checkpoint, reduce_lr, early_stop],class_weight=class_weights
)
# Out:
# Epoch 1/30
# 55/55 [==============================] - ETA: 0s - loss: 0.5269 - accuracy: 0.7195
# Epoch 1: val_loss improved from inf to 0.60199, saving model to best_model.h5
# 55/55 [==============================] - 124s 1s/step - loss: 0.5269 - accuracy: 0.7195 - val_loss: 0.6020 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 2/30
# 55/55 [==============================] - ETA: 0s - loss: 0.3197 - accuracy: 0.8685
# Epoch 2: val_loss did not improve from 0.60199
# 55/55 [==============================] - 57s 1s/step - loss: 0.3197 - accuracy: 0.8685 - val_loss: 0.6773 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 3/30
# 55/55 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.8887
# Epoch 3: val_loss did not improve from 0.60199
# 55/55 [==============================] - 58s 1s/step - loss: 0.2656 - accuracy: 0.8887 - val_loss: 1.2084 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 4/30
# 55/55 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9126
# Epoch 4: val_loss did not improve from 0.60199
# 55/55 [==============================] - 56s 1s/step - loss: 0.2190 - accuracy: 0.9126 - val_loss: 1.0902 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 5/30
# 55/55 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9203
# Epoch 5: val_loss did not improve from 0.60199
# 55/55 [==============================] - 57s 1s/step - loss: 0.2080 - accuracy: 0.9203 - val_loss: 1.0259 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 6/30
# 55/55 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9194
# Epoch 6: val_loss did not improve from 0.60199
# 55/55 [==============================] - 56s 1s/step - loss: 0.2098 - accuracy: 0.9194 - val_loss: 0.8096 - val_accuracy: 0.7342 - lr: 1.0000e-04
# Epoch 7/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9268
# Epoch 7: val_loss improved from 0.60199 to 0.45729, saving model to best_model.h5
# 55/55 [==============================] - 59s 1s/step - loss: 0.1876 - accuracy: 0.9268 - val_loss: 0.4573 - val_accuracy: 0.8051 - lr: 1.0000e-04
# Epoch 8/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9359
# Epoch 8: val_loss improved from 0.45729 to 0.14543, saving model to best_model.h5
# 55/55 [==============================] - 58s 1s/step - loss: 0.1627 - accuracy: 0.9359 - val_loss: 0.1454 - val_accuracy: 0.9462 - lr: 1.0000e-04
# Epoch 9/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9345
# Epoch 9: val_loss improved from 0.14543 to 0.13881, saving model to best_model.h5
# 55/55 [==============================] - 56s 1s/step - loss: 0.1649 - accuracy: 0.9345 - val_loss: 0.1388 - val_accuracy: 0.9479 - lr: 1.0000e-04
# Epoch 10/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9385
# Epoch 10: val_loss did not improve from 0.13881
# 55/55 [==============================] - 58s 1s/step - loss: 0.1557 - accuracy: 0.9385 - val_loss: 0.1929 - val_accuracy: 0.9085 - lr: 1.0000e-04
# Epoch 11/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9431
# Epoch 11: val_loss did not improve from 0.13881
# 55/55 [==============================] - 56s 1s/step - loss: 0.1540 - accuracy: 0.9431 - val_loss: 0.1758 - val_accuracy: 0.9197 - lr: 1.0000e-04
# Epoch 12/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9436
# Epoch 12: val_loss improved from 0.13881 to 0.11032, saving model to best_model.h5
# 55/55 [==============================] - 57s 1s/step - loss: 0.1563 - accuracy: 0.9436 - val_loss: 0.1103 - val_accuracy: 0.9556 - lr: 1.0000e-04
# Epoch 13/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1333 - accuracy: 0.9499
# Epoch 13: val_loss did not improve from 0.11032
# 55/55 [==============================] - 56s 1s/step - loss: 0.1333 - accuracy: 0.9499 - val_loss: 0.2348 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 14/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9507
# Epoch 14: val_loss did not improve from 0.11032
# 55/55 [==============================] - 56s 1s/step - loss: 0.1382 - accuracy: 0.9507 - val_loss: 0.2079 - val_accuracy: 0.9154 - lr: 1.0000e-04
# Epoch 15/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9482
# Epoch 15: val_loss did not improve from 0.11032
# 55/55 [==============================] - 56s 1s/step - loss: 0.1275 - accuracy: 0.9482 - val_loss: 0.2869 - val_accuracy: 0.8915 - lr: 1.0000e-04
# Epoch 16/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1257 - accuracy: 0.9507
# Epoch 16: val_loss did not improve from 0.11032
# 55/55 [==============================] - 57s 1s/step - loss: 0.1257 - accuracy: 0.9507 - val_loss: 0.2159 - val_accuracy: 0.9188 - lr: 1.0000e-04
# Epoch 17/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1280 - accuracy: 0.9539
# Epoch 17: val_loss did not improve from 0.11032
# 55/55 [==============================] - 58s 1s/step - loss: 0.1280 - accuracy: 0.9539 - val_loss: 0.1784 - val_accuracy: 0.9316 - lr: 1.0000e-04
# Epoch 18/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9550
# Epoch 18: val_loss did not improve from 0.11032
# 55/55 [==============================] - 56s 1s/step - loss: 0.1134 - accuracy: 0.9550 - val_loss: 0.1633 - val_accuracy: 0.9393 - lr: 1.0000e-04
# Epoch 19/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9587
# Epoch 19: val_loss did not improve from 0.11032
# 55/55 [==============================] - 66s 1s/step - loss: 0.1045 - accuracy: 0.9587 - val_loss: 0.2252 - val_accuracy: 0.9154 - lr: 1.0000e-04
# Epoch 20/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9636
# Epoch 20: val_loss did not improve from 0.11032
# 55/55 [==============================] - 61s 1s/step - loss: 0.1146 - accuracy: 0.9636 - val_loss: 0.2021 - val_accuracy: 0.9188 - lr: 1.0000e-04
# Epoch 21/30
# 55/55 [==============================] - ETA: 0s - loss: 0.1179 - accuracy: 0.9576
# Epoch 21: val_loss did not improve from 0.11032
# 55/55 [==============================] - 57s 1s/step - loss: 0.1179 - accuracy: 0.9576 - val_loss: 0.2154 - val_accuracy: 0.9248 - lr: 1.0000e-04
# Epoch 22/30
# 55/55 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9613
# Epoch 22: val_loss did not improve from 0.11032
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 55/55 [==============================] - 56s 1s/step - loss: 0.0998 - accuracy: 0.9613 - val_loss: 0.3195 - val_accuracy: 0.8880 - lr: 1.0000e-04

# %%
loss, accuracy = model.evaluate(test_generator, batch_size=128)
# Out:
# 1/1 [==============================] - 22s 22s/step - loss: 0.3851 - accuracy: 0.8910

# %%
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 0.3850992023944855
# Test accuracy: 0.8909710645675659

# %%
x_test, y_test = test_generator.next()

# %%
test_loss, test_acc = model.evaluate_generator(test_generator, steps=50)
print('test acc:', test_acc)
# Out:
# <ipython-input-48-a056cf674a87>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_acc = model.evaluate_generator(test_generator, steps=50)
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 50 batches). You may need to use the repeat() function when building your dataset.
# test acc: 0.8909710645675659

# %%
y_pred = model.predict(x_test)
y_pred_classes = np.round(y_pred)
auc_score = roc_auc_score(y_test, y_pred)
# Out:
# 37/37 [==============================] - 11s 37ms/step

# %%
recall = recall_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes)
precision = precision_score(y_test, y_pred_classes)

# %%
print('Test AUC : ',auc_score)
print('Test recall: ',recall)
print('Test f1 : ',f1)
print('Test precision : ',precision)
# Out:
# Test AUC :  0.9903529653794158
# Test recall:  0.8551401869158879
# Test f1 :  0.9195979899497487
# Test precision :  0.9945652173913043

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
cm = confusion_matrix(y_test, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %%
from sklearn.metrics import roc_curve , auc

fpr, tpr, _ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.legend() 
plt.show()
model.save('my_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %%
cp /content/drive/MyDrive/my_model.h5 /content

# %%
model = tf.keras.models.load_model('/content/my_model.h5')

# %%
def preprocess_image(img_path, target_size=(128, 128)):
    img = image.load_img(img_path, target_size=target_size, color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  
    return img_array

# %%
def predict_image(img_path):
    img_array = preprocess_image(img_path)
    prediction = model.predict(img_array)
    if prediction < 0.5:
        return "Normal"
    else:
        return "Pneumonia"

# %%
import matplotlib.pyplot as plt
def plot_image_with_label(img_path, label):
    img = image.load_img(img_path, color_mode='grayscale')
    plt.imshow(img, cmap='gray')
    plt.title(label)
    plt.axis('off')
    plt.show()

# %%
img1 = '/content/N1.jpeg'
img2 = '/content/P1.jpeg'
img3 = '/content/P2.jpeg'
img4 = '/content/P3.jpeg'

# %%
result = predict_image(img1)
print(f"The X-ray image is predicted to be: {result}")
plot_image_with_label(img1, f"Prediction: {result}")
# Out:
# 1/1 [==============================] - 6s 6s/step
# The X-ray image is predicted to be: Normal

# %%
result = predict_image(img2)
print(f"The X-ray image is predicted to be: {result}")
plot_image_with_label(img2, f"Prediction: {result}")
# Out:
# 1/1 [==============================] - 0s 187ms/step
# The X-ray image is predicted to be: Pneumonia

# %%
result = predict_image(img3)
print(f"The X-ray image is predicted to be: {result}")
plot_image_with_label(img3, f"Prediction: {result}")
# Out:
# 1/1 [==============================] - 0s 108ms/step
# The X-ray image is predicted to be: Pneumonia

# %%
result = predict_image(img4)
print(f"The X-ray image is predicted to be: {result}")
plot_image_with_label(img4, f"Prediction: {result}")
# Out:
# 1/1 [==============================] - 0s 117ms/step
# The X-ray image is predicted to be: Pneumonia
